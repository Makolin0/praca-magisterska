# %% [markdown]
# # Instalowanie i kompilacja programów użytych w pracy

# %%
# %pip install chess python-chess
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 9.5 MB/s  0:00:00m eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for chess: filename=chess-1.11.2-py3-none-any.whl size=147879 sha256=58b5b2bd5a1bc3b1391362c96cf372aa338045c95cf3799b2ae3f5770d7ed32c
#   Stored in directory: /home/adamz/.cache/pip/wheels/83/1f/4e/8f4300f7dd554eb8de70ddfed96e94d3d030ace10c5b53d447
# Successfully built chess
# ...

# %%
# !git clone https://github.com/official-stockfish/nnue-pytorch.git
# Out:
# Cloning into 'nnue-pytorch'...
# remote: Enumerating objects: 2822, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 2822 (delta 5), reused 0 (delta 0), pack-reused 2807 (from 2)
# Receiving objects: 100% (2822/2822), 3.54 MiB | 8.94 MiB/s, done.
# Resolving deltas: 100% (1782/1782), done.

# %%
# %cd ~/Documents/praca-magisterska/
# Out:
# /home/adamz/Documents/praca-magisterska

# %%
# !pwd
# Out:
# /home/adamz/Documents/praca-magisterska

# %%
# !git clone https://github.com/official-stockfish/Stockfish.git sf_source
# !cd sf_source/src
# !make -j profile-build
# !mv stockfish ../../
# !cd ../..
# !rm -rf sf_source
# Out:
# Cloning into 'sf_source'...
# remote: Enumerating objects: 41293, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 41293 (delta 22), reused 17 (delta 17), pack-reused 41243 (from 2)
# Receiving objects: 100% (41293/41293), 19.11 MiB | 10.62 MiB/s, done.
# Resolving deltas: 100% (31828/31828), done.
# make: *** No rule to make target 'profile-build'.  Stop.
# mv: cannot stat 'stockfish': No such file or directory

# %%
# !git clone -b tools https://github.com/official-stockfish/Stockfish.git sf_source_tools
# %cd sf_source_tools/src
# !make -j profile-build ARCH=x86-64-modern
# !mv stockfish ../../stockfish-tools
# %cd ../..
# Out:
# Cloning into 'sf_source_tools'...
# remote: Enumerating objects: 41293, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 41293 (delta 22), reused 17 (delta 17), pack-reused 41240 (from 2)
# Receiving objects: 100% (41293/41293), 19.11 MiB | 10.44 MiB/s, done.
# Resolving deltas: 100% (31826/31826), done.
# /home/adamz/praca-magisterska/sf_source_tools/src
# Default net: nn-3c0aa92af1da.nnue
# ...
#
# Config:
# debug: 'no'
# sanitize: 'none'
# optimize: 'yes'
# arch: 'x86_64'
# bits: '64'
# kernel: 'Linux'
# os: 'GNU/Linux'
# prefetch: 'yes'
# popcnt: 'yes'
# pext: 'no'
# sse: 'yes'
# mmx: 'no'
# sse2: 'yes'
# ssse3: 'yes'
# sse41: 'yes'
# avx2: 'no'
# avxvnni: 'no'
# avx512: 'no'
# vnni256: 'no'
# vnni512: 'no'
# neon: 'no'
# arm_version: '0'
#
# Flags:
# CXX: g++
# ...

# %%
# !git clone https://github.com/kentdjb/pgn-extract pgn-extract-source
# %cd pgn-extract-source
# !make
# !mv pgn-extract ../
# %cd ../
# Out:
# Cloning into 'pgn-extract-source'...
# remote: Enumerating objects: 424, done.
# remote: Counting objects: 100% (424/424), done.
# remote: Compressing objects: 100% (260/260), done.
# remote: Total 424 (delta 246), reused 324 (delta 150), pack-reused 0 (from 0)
# Receiving objects: 100% (424/424), 480.97 KiB | 4.45 MiB/s, done.
# Resolving deltas: 100% (246/246), done.
# /Users/adamz/Developer/praca magisterska/pgn-extract-source
# gcc -c -pedantic -Wall -Wshadow -Wformat -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes -Wwrite-strings -Wsign-compare -Wimplicit-function-declaration -g -I/usr/local/lib/ansi-include -std=c99  -O3 grammar.c
# gcc -c -pedantic -Wall -Wshadow -Wformat -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes -Wwrite-strings -Wsign-compare -Wimplicit-function-declaration -g -I/usr/local/lib/ansi-include -std=c99  -O3 lex.c
# ...

# %%
# %cd nnue-pytorch
# Out:
# /home/adamz/praca-magisterska/nnue-pytorch

# %%
# !pip install -r requirements.txt
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
import torchvision
print(f"Torch version: {torch.__version__}")
print(f"TorchVision version: {torchvision.__version__}")
try:
    from torchvision.ops import nms
    print("Success: NMS operator found.")
except Exception as e:
    print(f"Failed: {e}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 import torch
# ----> 2 import torchvision
#       3 print(f"Torch version: {torch.__version__}")
#       4 print(f"TorchVision version: {torchvision.__version__}")
#       5 try:
#
# File ~/praca-magisterska/.venv/lib/python3.14/site-packages/torchvision/__init__.py:8
#       5 # Don't re-order these, we need to load the _C extension (done when importing
#       6 # .extension) before entering _meta_registrations.
#       7 from . import extension  # usort:skip  # noqa: F401
# ----> 8 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      10 try:
#      11     from .version import __version__  # noqa: F401
#
# File ~/praca-magisterska/.venv/lib/python3.14/site-packages/torchvision/_meta_registrations.py:163
#     153     torch._check(
# ...

# %%
# !python serialize.py
# Out:
# Traceback (most recent call last):
#   File "/home/adamz/praca-magisterska/nnue-pytorch/serialize.py", line 10, in <module>
#     import model as M
#   File "/home/adamz/praca-magisterska/nnue-pytorch/model/__init__.py", line 1, in <module>
#     from .callbacks import WeightClippingCallback
#   File "/home/adamz/praca-magisterska/nnue-pytorch/model/callbacks.py", line 1, in <module>
#     import lightning as L
#   File "/home/adamz/praca-magisterska/.venv/lib/python3.14/site-packages/lightning/__init__.py", line 20, in <module>
#     from lightning.pytorch.callbacks import Callback  # noqa: E402
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adamz/praca-magisterska/.venv/lib/python3.14/site-packages/lightning/pytorch/__init__.py", line 27, in <module>
#     from lightning.pytorch.callbacks import Callback  # noqa: E402
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
