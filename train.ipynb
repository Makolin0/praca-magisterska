# %%
# !python train.py \
    /data/nnue_input.binpack \
    --validation-datasets /data/nnue_input.binpack \
    --default-root-dir /data/trained_nets/ \
    --gpus 0 \
    --threads 4 \
    --batch-size 16384 \
    --lambda 0.8 \
    --max-epochs 50 \
    --features "HalfKAv2_hm^"
